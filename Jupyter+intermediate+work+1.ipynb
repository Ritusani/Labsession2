# %%
import pandas as pd ## using pandas to work on excel files

# %%
data = pd.read_excel("data_breaches.xlsx") ##reading the file that I uploaded on jupyter

# %%
data = data.drop('alternative name') #trying to remove a column using drop command
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7af7b87d62a4> in <module>()
# ----> 1 data = data.drop('alternative name')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
data = data.dropna(axis=1, how='all') #removing all the null values from the table

# %%
data = data.drop('alternative name', axis=1) #to remove this coloumn from the table

# %%
data #to display the table
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
#trying to delete multiple columns 
data = data.drop('story','interesting story', 'NO OF RECORDS STOLEN', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link',axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-05cb1b6be7db> in <module>()
# ----> 1 data = data.drop('story','interesting story', 'NO OF RECORDS STOLEN', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link',axis=1)
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
data = data.drop('story','interesting story', 'NO OF RECORDS STOLEN', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-20c97727a5cb> in <module>()
# ----> 1 data = data.drop('story','interesting story', 'NO OF RECORDS STOLEN', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link')
#
# TypeError: drop() takes from 2 to 6 positional arguments but 8 were given

# %%
data = data.drop('story','interesting story', 'NO OF RECORDS STOLEN', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-041aea832bd1> in <module>()
# ----> 1 data = data.drop('story','interesting story', 'NO OF RECORDS STOLEN', 'Exclude')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2148         dropped : type of caller
#    2149         """
# -> 2150         inplace = validate_bool_kwarg(inplace, 'inplace')
#    2151         axis = self._get_axis_number(axis)
#    2152         axis_name = self._get_axis_name(axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_validators.py in validate_bool_kwarg(value, arg_name)
#     223         raise ValueError('For argument "%s" expected type bool, '
#     224                          'received type %s.' %
# --> 225                          (arg_name, type(value).__name__))
#     226     return value
#
# ...

# %%
data = data.drop('story', axis=1)

# %%
## to rename the columns 
data1=data.rename(columns={'alternative name':'Alternative Name',
                        'story':'Story',
                        'YEAR':'Year',
                        'records lost':'Records Lost',
                        'ORGANISATION':'Organisation',
                        'METHOD OF LEAK':'Method Of Leak',
                        'interesting story':'Interesting Story',
                        'NO OF RECORDS STOLEN':'No of Records',
                        'DATA SENSITIVITY':'Data Sensitivity',
                        })

# %%
## trying to delete coloumns in various other ways
data1.drop(data1.ix[:,'Interesting Story':'No of Records'].head(0).columns, axis=1)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# ...

# %%
data1 = data1.drop(['interesting story', 'No of Records', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-495da575f83a> in <module>()
# ----> 1 data1 = data1.drop(['interesting story', 'No of Records', 'Exclude', 'Unnamed: 13', '1st source link','2nd source link'],axis=1)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
new_axis = axis.drop(labels, level=level, errors=errors)
            else:
               new_axis = axis.drop(labels, errors=errors)
                dropped = self.reindex(**{axis_name: new_axis})
             try:
                if errors != 'ignore':
               raise ValueError('labels %s not contained in axis' %
                                 labels[mask])
           indexer = indexer[~mask]
           return self.delete(indexer)
# Out:
#   File "<tokenize>", line 5
#     try:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
new_axis = axis.drop(labels, level=level, errors=errors)
    else:
        new_axis = axis.drop(labels, errors=errors)
        dropped = self.reindex(**{axis_name: new_axis})
    try:
    if errors != 'ignore':
        raise ValueError('labels %s not contained in axis' %
                                 labels[mask])
        indexer = indexer[~mask]
return self.delete(indexer)
# Out:
#   File "<ipython-input-20-cd5277d504aa>", line 2
#     else:
#     ^
# IndentationError: unexpected indent

# %%
new_axis = axis.drop(labels, level=level, errors=errors)
else:
        new_axis = axis.drop(labels, errors=errors)
        dropped = self.reindex(**{axis_name: new_axis})
try:
    if errors != 'ignore':
        raise ValueError('labels %s not contained in axis' %
                                 labels[mask])
        indexer = indexer[~mask]
return self.delete(indexer)
# Out:
#   File "<ipython-input-21-7a546b3471d5>", line 2
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
  new_axis = axis.drop(labels, level=level, errors=errors)
        else:
        new_axis = axis.drop(labels, errors=errors)
        dropped = self.reindex(**{axis_name: new_axis})
        try:
        if errors != 'ignore':
            raise ValueError('labels %s not contained in axis' %
                                 labels[mask])
            indexer = indexer[~mask]
    return self.delete(indexer)
# Out:
#   File "<tokenize>", line 10
#     return self.delete(indexer)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
 new_axis = axis.drop(labels, level=level, errors=errors)
        else:
        new_axis = axis.drop(labels, errors=errors)
        dropped = self.reindex(**{axis_name: new_axis})
        try:
        if errors != 'ignore':
            raise ValueError('labels %s not contained in axis' %
                                 labels[mask])
            indexer = indexer[~mask]
        return self.delete(indexer)
# Out:
#   File "<ipython-input-23-2d1a65891b8f>", line 2
#     else:
#     ^
# IndentationError: unexpected indent

# %%
 new_axis = axis.drop(labels, level=level, errors=errors)
    else:
        new_axis = axis.drop(labels, errors=errors)
        dropped = self.reindex(**{axis_name: new_axis})
    try:
        if errors != 'ignore':
            raise ValueError('labels %s not contained in axis' %
                                 labels[mask])
            indexer = indexer[~mask]
    return self.delete(indexer)
# Out:
#   File "<ipython-input-24-a1140e3ac6a9>", line 2
#     else:
#     ^
# IndentationError: unexpected indent

# %%
## displaying columns that are required
data1[['Entity','Year','Records Lost','Organisation','Method Of Leak','Data Sensitivity']]
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-8e2f36e89885> in <module>()
# ----> 1 data1[['Entity','Year','Records Lost','Organisation','Method of Leak','Data Sensitivity']]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
data1[['Entity','Year','Records Lost','Organisation','Method Of Leak','Data Sensitivity']]
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
## saving data as an new excel file at a particuar place by specifying a path
data1.to_excel('Macintosh HD/Users/Ritu/Desktop/lab_2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-f36fbe06d87b> in <module>()
# ----> 1 data1.to_excel('Macintosh HD/Users/Ritu/Desktop/lab_2.xlsx')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1422         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1423                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1424                         engine=engine)
#    1425
#    1426     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# /usr/local/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...

# %%
## to resole the "Module not found error"
import openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-f5ea1cbb6934> in <module>()
# ----> 1 import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
## to save the data in csv format file
import csv

# %%
## to replace the numbers with years
data1.Year = data1.Year.replace({"0": "2004", "1": "2005","2": "2006", "3": "2007"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-4264fda49e7f> in <module>()
# ----> 1 data1.Year = data1.Year.replace({"0": "2004", "1": "2005","2": "2006", "3": "2007"})
#
# AttributeError: 'NoneType' object has no attribute 'Year'

# %%
## this command worked but when I displayed the data to see- any changes didn't happen 
data1.Year = data1.Year.replace({"0": "2004", "1": "2005"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-29a41833439e> in <module>()
#       1 ## this command worked but
# ----> 2 data1.Year = data1.Year.replace({"0": "2004", "1": "2005"})
#
# AttributeError: 'NoneType' object has no attribute 'Year'

# %%
data1.Year
# Out:
# 0      years are encoded (0=2004, 8 = 2012, 9 = 2013,...
# 1                                                      0
# 2                                                      1
# 3                                                      1
# 4                                                      1
# 5                                                      1
# 6                                                      2
# 7                                                      2
# 8                                                      2
# 9                                                      2
# 10                                                     2
# 11                                                     2
# 12                                                     3
# 13                                                     3
# 14                                                     3
# 15                                                     3
# ...

# %%
print (data1)
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
## I tried to change this command a bit but again it didn't change anything
data1=data1.Year.replace({'0': 1, 'bad': 2004, '1': 2005}, inplace=True)

# %%
print (data1)
# Out:
# None

# %%
data
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data1 = data.YEAR.replace({'0': 1, 'bad': 2004, '1': 2005}, inplace=True)

# %%
data1

# %%
data
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
## created a new data frame 'date2' to do the rest of the changes 
data2=data.rename(columns={'alternative name':'Alternative Name',
                        'story':'Story',
                        'YEAR':'Year',
                        'records lost':'Records Lost',
                        'ORGANISATION':'Organisation',
                        'METHOD OF LEAK':'Method Of Leak',
                        'interesting story':'Interesting Story',
                        'NO OF RECORDS STOLEN':'No of Records',
                        'DATA SENSITIVITY':'Data Sensitivity',
                        })

# %%
## tried other syntax to replace the numbers with years 
data2.replace(['0', '1', '2', '3', '4'], [2004, 2005, 2006, 2007, 2008])
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
## years column 
data2['Year'] = data2['Year'].replace(['0', '1', '2', '3', '4'], [2004, 2005, 2006, 2007, 2008])

# %%
data2
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
updated_year = {"Year":{0:2004,1:2005,2:2006,3:2007,4:2008,5:2009,6:2010,7:2011,8:2012,9:2013,10:2014,11:2015,12:2016,13:2017,14:2018}}

# %%
data3=data2.replace(updated_year)

# %%
data3
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data2.replace(updated_year)
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data2
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data3
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data3 = data3.drop('Interesting Story', axis=1)

# %%
data3 = data3.drop('No of Records', axis=1)

# %%
data3 = data3.drop('Exclude', axis=1)

# %%
data3 = data3.drop('Unnamed: 13', axis=1)

# %%
data3 = data3.drop('1st source link', axis=1)

# %%
data3 = data3.drop('2nd source link', axis=1)

# %%
data3 = data3.drop('3rd source', axis=1)

# %%
data3 = data3.drop('source name', axis=1)

# %%
data3
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data_final=data3.rename(columns={'Data Sensitivity':'Sensitivity'})

# %%
data_final
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
sensi = {"Sensitivity":{1:'Email Address/Online info',20:'SSN/Personal Details',300:'Credit card info',4000:'Passwords/Health Records',50000:'Bank Account Details'}}

# %%
data_final.replace(sensi)
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
data_final.to_csv('Lab2.csv')

# %%
data_final = pd.read_csv('Lab2.csv')

# %%
Lab2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-d2b666f99425> in <module>()
# ----> 1 Lab2
#
# NameError: name 'Lab2' is not defined

# %%
pwd
# Out:
# '/home/dv/notebooks'

# %%
cd Ritu/Desktop
# Out:
# [Errno 2] No such file or directory: 'Ritu/Desktop'
# /home/dv/notebooks

# %%
cd documents
# Out:
# [Errno 2] No such file or directory: 'documents'
# /home/dv/notebooks

# %%
llab2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-16c3151cd94e> in <module>()
# ----> 1 lab2
#
# NameError: name 'lab2' is not defined

# %%
Lab2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-d2b666f99425> in <module>()
# ----> 1 Lab2
#
# NameError: name 'Lab2' is not defined

# %%
data_final
# Out:
#      Unnamed: 0                                          Entity  \
# 0             0                                             NaN
# 1             1                                             AOL
# 2             2                       Automatic Data Processing
# 3             3                                 Ameritrade Inc.
# 4             4                                       Citigroup
# 5             5                     Cardsystems Solutions Inc.
# 6             6                                 Hewlett Packard
# 7             7                      Countrywide Financial Corp
# 8             8                                            KDDI
# 9             9                      T-Mobile, Deutsche Telecom
# 10           10                                             AOL
# 11           11                          US Dept of Vet Affairs
# 12           12                                   Texas Lottery
# 13           13    City and Hackney Teaching Primary Care Trust
# ...

# %%
df =
